# %%
import unittest

from sqlalchemy import *
from sqlalchemy.orm import create_session
from sqlalchemy.ext.declarative import declarative_base
from datetime import datetime
from sqlalchemy.orm import contains_eager, joinedload
from sqlalchemy.orm import relationship

#Create and engine and get the metadata
Base = declarative_base()
engine = create_engine('sqlite:///Northwind_large.sqlite', echo=True)
metadata = MetaData(bind=engine)


#Reflect each database table we need to use, using metadata
class Customer(Base):
    __table__ = Table('Customer', metadata, autoload=True)
    orders = relationship("Order", backref="customer")

class Shipper(Base):
    __table__ = Table('Shipper', metadata, autoload=True)
    orders = relationship("Order", backref="shipper")

class Employee(Base):
    __table__ = Table('Employee', metadata, autoload=True)
#    orders = relationship("Order", backref="employee")
    territories = relationship('Territory', secondary=Table('EmployeeTerritory', metadata, autoload=True))

class Territory(Base):
    __table__ = Table('Territory', metadata, autoload=True)
    region = relationship('Region', backref='territories')

class Region(Base):
    __table__ = Table('Region', metadata, autoload=True)


class Order(Base):
    __table__ = Table('Order', metadata, autoload=True)
    products = relationship('Product', secondary=Table('OrderDetail', metadata, autoload=True))
    employee = relationship('Employee', backref='orders')

class Product(Base):
    __table__ = Table('Product', metadata, autoload=True)
    supplier = relationship('Supplier', backref='products')
    category = relationship('Category', backref='products') 

class Supplier(Base):
    __table__ = Table('Supplier', metadata, autoload=True)

class Category(Base):
    __table__ = Table('Category', metadata, autoload=True)


class Test(unittest.TestCase):

    def setUp(self):
        #Create a session to use the tables    
        self.session = create_session(bind=engine)        

    def tearDown(self):
        self.session.close()

    def test_withJoins(self):
        q = self.session.query(Customer)
        q = q.join(Order)
        q = q.join(Shipper)
        q = q.filter(Customer.CustomerID =='ALFKI')
        q = q.filter(Order.OrderID=='10643')
        q = q.filter(Shipper.ShipperID=='1')
        q = q.options(contains_eager(Customer.orders, Order.shipper))
        res = q.all()
        cus = res[0]
        ord = cus.orders[0]
        shi = ord.shipper
        self.assertEqual(shi.Phone, '(503) 555-9831')
# Out:
# 2020-02-02 13:48:11,658 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-02-02 13:48:11,663 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,667 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-02-02 13:48:11,670 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,676 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Customer")
# 2020-02-02 13:48:11,679 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,686 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2020-02-02 13:48:11,689 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,692 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("Customer")
# 2020-02-02 13:48:11,694 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,695 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("Customer")
# 2020-02-02 13:48:11,696 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,698 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2020-02-02 13:48:11,699 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,705 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Customer")
# 2020-02-02 13:48:11,712 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,718 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Customer")
# 2020-02-02 13:48:11,721 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,724 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("sqlite_autoindex_Customer_1")
# 2020-02-02 13:48:11,726 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,728 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2020-02-02 13:48:11,735 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,747 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Shipper")
# 2020-02-02 13:48:11,750 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11,756 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2020-02-02 13:48:11,758 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:11
INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Order")
# 2020-02-02 13:48:12,058 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,060 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Order")
# 2020-02-02 13:48:12,061 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,066 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Order")
# 2020-02-02 13:48:12,069 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,071 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Order")
# 2020-02-02 13:48:12,073 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,074 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2020-02-02 13:48:12,076 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,081 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("OrderDetail")
# 2020-02-02 13:48:12,082 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,086 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2020-02-02 13:48:12,089 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,091 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("OrderDetail")
# 2020-02-02 13:48:12,095 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,098 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("OrderDetail")
# 2020-02-02 13:48:12,100 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,103 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2020-02-02 13:48:12,105 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,109 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("OrderDetail")
# 2020-02-02 13:48:12,111 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,113 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("OrderDetail")
# 2020-02-02 13:48:12,114 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,116 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("sqlite_autoindex_OrderDetail_1")
# 2020-02-02 13:48:12,118 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,120 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2020-02-02 13:48:12,122 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,133 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Product")
# 2020-02-02 13:48:12,136 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,142 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2020-02-02 13:48:12,144 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,146 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("Product")
# 2020-02-02 13:48:12,148 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,149 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("Product")
# 2020-02-02 13:48:12,150 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,151 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2020-02-02 13:48:12,153 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,155 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Product")
# 2020-02-02 13:48:12,157 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,158 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Product")
# 2020-02-02 13:48:12,159 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,161 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Product")
# 2020-02-02 13:48:12,162 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,167 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Product")
# 2020-02-02 13:48:12,169 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,171 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2020-02-02 13:48:12,172 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,183 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Supplier")
# 2020-02-02 13:48:12,184 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,191 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2020-02-02 13:48:12,193 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,201 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("Supplier")
# 2020-02-02 13:48:12,204 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,207 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("Supplier")
# 2020-02-02 13:48:12,210 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,211 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2020-02-02 13:48:12,212 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,214 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Supplier")
# 2020-02-02 13:48:12,215 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,217 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Supplier")
# 2020-02-02 13:48:12,218 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,219 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Supplier")
# 2020-02-02 13:48:12,221 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,223 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Supplier")
# 2020-02-02 13:48:12,224 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,225 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2020-02-02 13:48:12,226 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,239 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Category")
# 2020-02-02 13:48:12,242 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,248 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2020-02-02 13:48:12,250 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,255 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("Category")
# 2020-02-02 13:48:12,261 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,263 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("Category")
# 2020-02-02 13:48:12,266 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,267 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2020-02-02 13:48:12,268 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,272 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Category")
# 2020-02-02 13:48:12,280 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,283 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Category")
# 2020-02-02 13:48:12,284 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,288 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("Category")
# 2020-02-02 13:48:12,295 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,298 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("Category")
# 2020-02-02 13:48:12,300 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-02 13:48:12,302 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2020-02-02 13:48:12,303 INFO sqlalchemy.engine.base.Engine ()
